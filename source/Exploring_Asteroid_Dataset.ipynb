# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Read in data
data = pd.read_csv('../data/Asteroid_Updated.csv')
# Out:
# /var/folders/1m/j_m6thdd69s0c7tmz363g86m0000gn/T/ipykernel_40887/1781482078.py:7: DtypeWarning: Columns (0,10,15,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../data/Asteroid_Updated.csv')

# %%
print(data)
# Out:
#            name         a         e          i          om           w  \
# 0         Ceres  2.769165  0.076009  10.594067   80.305532   73.597694
# 1        Pallas  2.772466  0.230337  34.836234  173.080063  310.048857
# 2          Juno  2.669150  0.256942  12.988919  169.852760  248.138626
# 3         Vesta  2.361418  0.088721   7.141771  103.810804  150.728541
# 4       Astraea  2.574249  0.191095   5.366988  141.576605  358.687607
# ...         ...       ...       ...        ...         ...         ...
# 839709      NaN  2.812945  0.664688   4.695700  183.310012  234.618352
# 839710      NaN  2.645238  0.259376  12.574937    1.620020  339.568072
# 839711      NaN  2.373137  0.202053   0.732484  176.499082  198.026527
# 839712      NaN  2.260404  0.258348   9.661947  204.512448  148.496988
# 839713      NaN  2.546442  0.287672   5.356238   70.709555  273.483265
#
#                q        ad     per_y  data_arc  ...     UB  IR  spec_B spec_T  \
# ...

# %%
selected_data = data[['a','e','i','om','w','q','ad','per_y','rot_per','diameter']]
selected_data = selected_data.sample(n=20000)

# %%
#Check over data for correlations
corr = selected_data.corr()
sns.heatmap(corr,annot = True,vmin=-1,vmax=1,center= 0, cmap='RdBu')
# Out:
# <Axes: >

# %%
sns.pairplot(data[['a','e','i','om','w','q','ad','per_y','diameter','class']].sample(n=2000), hue = 'class')

# %%
sns.pairplot(data[['a','q','per_y','diameter','i','ad','rot_per','G','H','class']].sample(n=100000), hue = 'class')
